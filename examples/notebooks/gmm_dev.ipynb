# %%
from scripts.fit_gmm import fit_gmm_ret
from scripts.load_and_preprocess import load_saved_data
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def find_first_file(directory: str, startswith: str):
    for filename in os.listdir(directory):
        if filename.startswith(startswith):
            return os.path.join(directory, filename)
    return None

# %%
ret_example_path = find_first_file("data/processed/INTERVAL_36", "sct_ret")

# %%
ret_example_path
# Out:
# 'data/processed/INTERVAL_36/sct_ret_[QC-40411102]_20140412_102414.npy'

# %%
ret_example, _, _ = load_saved_data(
    "data/processed/INTERVAL_36/sct_ret_[QC-52921101]_20151124_095540.npy"
)

# %%
plt.scatter(ret_example[:, 0], ret_example[:, 1], s=1)
